# %% [markdown]
# ## Task 06 👨🏻‍💻
# Face Recognition
#
# #####  Description:
# ❄️ Create a program that perform below mentioned task upon recognizing a particular face.
#
# 📌 When it recognize your face then -
# 👉 It send mail to your mail id by writing this is face of your_name.
# 👉 Second it send whatsapp message to your friend, it can be anything.
#
# 📌 When it recognize second  face, it can be your friend or family members face.
# 👉 Create EC2 instance in the AWS using CLI.
# 👉 Create 5 GB EBS volume and attach it to the instance.

# %% [markdown]
# ### Step 1 - Create Training Data
# Collect sample of user to be recoginized

# %%
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
username = input("Write username to be recoginzed:");
def face_extractor(img):
    # Load HAAR face classifier


# Load functions

    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/user/'+username +"_"+ str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Not found sample : " +str(count))
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Sample collection Complete")
# Out:
# Write username to be recoginzed:Sharuk
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# Not found sample : 0
# ...

# %% [markdown]
# ### Step 2 - Train Model
# To load the sample in machine

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/user/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []
username =[]
# Open training images in our datapath
# Create a numpy array for training data

for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    username.append(str(onlyfiles[i]).split(".")[0])#username
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)



# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

face_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
face_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %% [markdown]
# ### Functions required to be called
# According to question function will be called to perform some activity
# ##### For whatsapp - to inform user is recognized through cmd
# ##### For mail - to inform user he is recoginized by machine mail id through cmd
# ##### For AWS - to create  ec2 instance and attach volume

# %%
import smtplib as s

from selenium import webdriver                                                                        
import time
import os
options = webdriver.ChromeOptions();
Address = os.environ.get('ADDRE_ENV');####
options.add_argument(r"--user-data-dir="+Address);
def whtapp_msg():
    print("now we will send message on whatsapp too!")
    driver = webdriver.Chrome(executable_path=r"./data/chromedriver.exe",options=options)##
    driver.get('https://web.whatsapp.com/')
    time.sleep(15)
    DM = driver.find_element_by_css_selector('span[title="Dynamics 🔸LW 🔹group"]')
    time.sleep(2)
    DM.click()
    text_input = driver.find_element_by_xpath("/html/body/div/div[1]/div[1]/div[4]/div[1]/footer/div[1]/div[2]/div/div[2]")##
    time.sleep(2)
    text_input.send_keys( "Hello Everyone!---generated by machine")
    time.sleep(2)
    text_input.send_keys(webdriver.common.keys.Keys.RETURN)
    time.sleep(5)
    driver.close()


def email():
    ob = s.SMTP("smtp.gmail.com",587)

    ob.starttls()
    email = os.environ.get('EMAIL_ENV')###
    password = os.environ.get('PASS_ENV')###

    ob.login(email, password )

    subject = "Generated by machine"
    body=name+" is recognized successfully "

    message="Subject:{}\n\n{}".format(subject,body)
    listOfAddress = ["sushmita246802@gmail.com"] # ###   #      #    
    ob.sendmail("mail.automation001",listOfAddress,message)

    print("Email has been sent successfully ! ")
    ob.quit()
    time.sleep(4)
    print("Lets cross check on mail for confirmation")
    driver1 = webdriver.Chrome(executable_path=r"./data/chromedriver.exe",options=options)
    driver1.get('https://mail.google.com/mail/')
    time.sleep(4)
    MM = driver1.find_element_by_xpath("/html/body/div[7]/div[3]/div/div[2]/div[1]/div[1]/div[1]/div/div/div/div[2]/div/div/div[1]/div[1]/div/div[4]/div/div/div[2]/span/a")
    time.sleep(1)
    MM.click()
    time.sleep(3)
    select = driver1.find_element_by_xpath("/html/body/div[7]/div[3]/div/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div[1]/div/div[2]/div[4]/div[2]/div/table/tbody/tr[1]")
    time.sleep(1)
    select.click()
    time.sleep(5)
    driver1.close()
    
def aws():
    os.system("aws ec2 run-instances --image-id ami-0ad704c126371a549 --instance-type t2.micro --count 1 --subnet-id subnet-9914fef2 --security-group-ids sg-56343b2b --key-name aws_lw2021")
    #different in every system
    print("EC2 instance has been created") 
    os.system("aws ec2 create-volume --size 5 --availability-zone ap-south-1a")# creating volume
    print("Volume has been created")
    i = input("Give instance-id:")
    v = input("Give volume-id:")
    os.system("aws ec2 attach-volume --volume-id "+v+" --instance-id "+i+" --device /dev/sdf")
    print("--------Now, volume has been attached to instance ---------")

# %% [markdown]
# ### Step 3 - Run Our Facial Recognition

# %%
import cv2
import numpy as np
import os 
from selenium import webdriver
flag=0
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = face_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'
            
       
    
        if confidence > 78:
            cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
            k=0
            myname = str(username[-1]).split("_")[0]
            name = "none"
            for j in username:
                if(k==results[0]):
                    name = (j.split("_")[0])
                    if(myname == name):
                        flag=1
                        break
                    flag=2
                    break
                k=k+1
     
            cv2.putText(image, "Hey "+name , (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
    
            cv2.imshow('Face Recognition', image )
            
            if cv2.waitKey(10) & 0xFF == ord('q'):
                sleep(5)
                break
            
            break
      
            
      
        else:
            
            cv2.putText(image, "I dont know, who r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
      
            if cv2.waitKey(10) & 0xFF == ord('q'):
                sleep(5)
                break
            
            break
      
            

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
        
cap.release()
cv2.destroyAllWindows()  
cv2.imshow("User identified",frame)
#delay upto any key enter
cv2.waitKey() # gives code of keyboard key according to key pressed noted by python 
#destroy window function
cv2.destroyAllWindows()
if(flag == 1):
    
    email()
    whtapp_msg()
    # print( "hi")
elif(flag==2):
    aws()
else:
    print ("Sorry! I failed to recoginize you")
# Out:
# Sorry! I failed to recoginize you
